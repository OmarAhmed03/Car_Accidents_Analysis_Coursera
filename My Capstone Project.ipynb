# %% [markdown]
# # This is The Coursera's Data Science Capstone Project

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing The dataset

# %%
df_acc = pd.read_csv('https://opendatatc.blob.core.windows.net/opendatatc/NCDB_2017.csv')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,2,5,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_acc.head()
# Out:
#    C_YEAR C_MNTH C_WDAY C_HOUR  C_SEV C_VEHS C_CONF C_RCFG C_WTHR C_RSUR  ...  \
# 0    2017      1      1     10      2      1     02     03      1      3  ...
# 1    2017      1      1     12      2      1     04     UU      1      5  ...
# 2    2017      1      1     00      2      1     03     UU      7      3  ...
# 3    2017      1      1     17      2      2     21     UU      1      1  ...
# 4    2017      1      1     17      2      2     21     UU      1      1  ...
#
#   V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_ISEV P_SAFE P_USER   C_CASE
# 0     01   UUUU   01     M    75    11      2     NN      1  2455950
# 1     01   UUUU   01     F    21    11      2     02      1  2455959
# 2     01   UUUU   01     F    34    11      2     02      1  2455998
# 3     01   UUUU   01     F    50    11      2     02      1  2456104
# 4     01   UUUU   01     M    63    11      1     NN      1  2456104
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Cleaning the dataset

# %%
nan_value = float("NaN")
df_acc.replace("UU", nan_value, inplace=True)
df_acc.replace("U", nan_value, inplace=True)
df_acc.replace("UUUU", nan_value, inplace=True)
df_acc.replace("X", nan_value, inplace=True)
df_acc.replace("XX", nan_value, inplace=True)
df_acc.replace("XXXX", nan_value, inplace=True)
df_acc.replace("Q", nan_value, inplace=True)
df_acc.replace("QQ", nan_value, inplace=True)
df_acc.replace("QQQQ", nan_value, inplace=True)
df_acc.replace("N", nan_value, inplace=True)
df_acc.replace("NN", nan_value, inplace=True)
df_acc.replace("NNNN", nan_value, inplace=True)
df_acc.dropna(inplace=True)

# %%
df_acc.drop(['V_ID', 'P_ID','C_CASE','C_WDAY', 'C_TRAF', 'C_VEHS','P_PSN', 'C_YEAR'], axis=1, inplace = True)

# %%
df_acc.reset_index(drop=True, inplace=True)
df_acc
# Out:
#        C_MNTH C_HOUR  C_SEV C_CONF C_RCFG C_WTHR C_RSUR C_RALN V_TYPE V_YEAR  \
# 0           1     06      2     04     02      1      4      2     01   2001
# 1           1     21      2     35     01      1      1      1     01   2016
# 2           1     21      2     35     01      1      1      1     01   2012
# 3           1     18      2     03     01      6      4      1     01   2009
# 4           1     18      2     03     01      6      4      1     01   2009
# 5           1     18      2     03     01      6      4      1     01   2009
# 6           1     08      2     04     01      1      5      1     01   2008
# 7           1     16      2     04     01      5      3      4     01   2005
# 8           1     17      2     23     01      4      4      1     01   2011
# 9           1     17      2     23     01      4      4      1     01   2011
# 10          1     17      2     23     01      4      4      1     01   2011
# 11          1     17      2     23     01      4      4      1     01   2011
# 12          1     17      2     23     01      4      4      1     01   2011
# 13          1     15      2     02     01      4      2      1     01   2009
# 14          1     15      2     02     01      4      2      1     01   2009
# 15          1     12      2     03     01      1      5      4     01   2006
# 16          1     12      2     04     01      4      3      4     01   2007
# 17          1     14      2     03     01      1      5      2     01   2006
# 18          1     12      2     04     03      2      4      4     01   2004
# 19          1     15      2     31     05      2      2      6     01   2007
# 20          1     15      2     31     05      2      2      6     01   2004
# 21          1     02      2     04     01      4      5      4     01   2004
# 22          1     09      2     23     01      1      5      3     01   2003
# 23          1     09      2     23     01      1      5      3     01   2012
# 24          1     21      2     04     01      1      5      3     01   2005
# 25          1     21      2     04     01      1      5      3     01   2005
# 26          1     22      2     04     01      2      4      3     01   2015
# 27          1     18      2     23     02      4      2      1     01   2010
# 28          1     18      2     23     02      4      2      1     01   2010
# 29          1     18      2     23     02      4      2      1     01   2010
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 165616     12     02      2     03     01      3      2      4     05   1985
# 165617     12     22      2     21     02      1      1      1     01   2003
# 165618     12     15      2     21     02      1      1      1     01   2013
# 165619     12     16      2     33     02      3      2      1     01   1999
# 165620     12     16      2     33     02      3      2      1     01   2016
# 165621     12     14      2     34     02      1      1      1     01   1992
# 165622     12     15      2     24     01      1      5      1     01   2012
# 165623     12     15      2     24     01      1      5      1     01   2012
# 165624     12     15      2     24     01      1      5      1     06   2017
# 165625     12     15      2     04     01      1      5      3     06   2005
# 165626     12     15      2     04     01      1      5      3     06   2005
# 165627     12     02      2     33     02      3      2      1     01   1998
# 165628     12     02      2     33     02      3      2      1     01   2010
# 165629     12     20      2     33     02      2      2      2     01   2017
# 165630     12     20      2     33     02      2      2      2     01   2017
# 165631     12     20      2     33     02      2      2      2     01   2004
# 165632     12     19      2     04     01      4      3      4     01   2009
# 165633     12     19      2     04     01      4      3      4     01   2009
# 165634     12     19      2     04     01      4      3      4     01   2009
# 165635     12     19      2     04     01      4      3      4     01   2009
# 165636     12     12      2     21     01      2      2      2     01   2001
# 165637     12     12      2     21     01      2      2      2     01   2001
# 165638     12     12      2     21     01      2      2      2     01   2005
# 165639     12     12      2     21     01      2      2      2     01   2005
# 165640     12     18      2     35     02      3      2      1     01   2004
# 165641     12     18      2     35     02      3      2      1     01   2007
# 165642     12     23      2     04     01      2      5      4     01   1996
# 165643     12     19      2     33     02      3      2      1     01   2006
# 165644     12     13      2     21     02      2      1      1     01   2007
# 165645     12     22      2     04     01      4      5      1     05   2010
#
#        P_SEX P_AGE P_ISEV P_SAFE P_USER
# 0          F    26      2     02      1
# 1          M    55      1     02      1
# 2          M    27      2     02      1
# 3          M    76      1     02      2
# 4          M    51      2     02      2
# 5          F    50      1     02      1
# 6          F    32      2     02      1
# 7          F    46      2     02      1
# 8          F    26      2     02      2
# 9          M    27      1     02      1
# 10         M    45      2     02      1
# 11         F    42      2     02      2
# 12         F    20      2     02      2
# 13         F    55      2     02      2
# 14         M    58      1     02      1
# 15         F    59      2     02      1
# 16         F    60      2     02      1
# 17         F    41      2     02      1
# 18         M    36      2     02      1
# 19         M    48      2     02      1
# 20         M    38      1     02      1
# 21         M    39      2     02      1
# 22         M    22      2     01      1
# 23         F    52      1     02      1
# 24         M    18      2     02      2
# 25         M    61      1     02      1
# 26         M    25      2     01      1
# 27         M    36      1     02      1
# 28         F    40      2     02      2
# 29         F    20      2     02      2
# ...      ...   ...    ...    ...    ...
# 165616     M    23      2     02      1
# 165617     F    64      2     02      1
# 165618     M    39      2     02      1
# 165619     M    52      1     02      1
# 165620     F    24      1     02      1
# 165621     F    54      1     02      1
# 165622     F    53      2     02      1
# 165623     M    54      1     02      2
# 165624     M    48      1     02      1
# 165625     F    57      1     02      1
# 165626     F    77      2     02      2
# 165627     F    17      2     02      1
# 165628     M    31      2     02      1
# 165629     F    34      2     02      1
# 165630     M    02      2     02      2
# 165631     F    18      2     02      1
# 165632     F    41      1     02      1
# 165633     M    36      2     02      2
# 165634     M    11      1     02      2
# 165635     M    09      1     02      2
# 165636     F    29      2     02      1
# 165637     F    08      1     02      2
# 165638     F    70      1     02      1
# 165639     M    82      2     02      2
# 165640     M    54      2     02      1
# 165641     F    24      1     02      1
# 165642     F    42      2     02      1
# 165643     F    23      2     02      1
# 165644     F    19      2     02      1
# 165645     M    38      2     02      2
#
# [165646 rows x 15 columns]

# %% [markdown]
# ## Number of accidents every Month

# %%
mnth = df_acc['C_MNTH'].value_counts()
mnth = mnth.to_frame()
mnth.index.rename('Month', inplace=True)
mnth = mnth.rename(columns={'C_MNTH':'Total'})
mnth.reset_index(inplace=True)
mnth = mnth.astype({"Month": int})
mnth.sort_values(by="Month", inplace=True)

# %%
mnth.plot(kind='bar', x='Month', figsize=(10, 6))
plt.title('Accidents according to months')
plt.show()

# %% [markdown]
# ## Number of accidents every hour

# %%
hour = df_acc['C_HOUR'].value_counts()
hour = hour.to_frame()
hour.index.rename('Hour', inplace=True)
hour = hour.rename(columns={'C_HOUR':'Total'})
hour.reset_index(inplace=True)
hour = hour.astype({"Hour": int})
hour.sort_values(by="Hour", inplace=True)
hour
# Out:
#     Hour  Total
# 18     0   1904
# 19     1   1533
# 21     2   1274
# 22     3   1030
# 23     4    910
# 20     5   1368
# 16     6   3680
# 12     7   6488
# 8      8   8518
# 11     9   7128
# 10    10   7516
# 7     11   8971
# 6     12  10583
# 5     13  10914
# 3     14  11475
# 2     15  14627
# 0     16  15454
# 1     17  15386
# 4     18  10973
# 9     19   7593
# 13    20   5656
# 14    21   5289
# 15    22   4200
# 17    23   3176

# %%
hour.plot(kind='bar', x='Hour', figsize=(10, 6))
plt.title('Accidents according to Hour')
plt.show()

# %% [markdown]
# ## Relationship between weather and accidents

# %%
weather = df_acc['C_WTHR'].value_counts()
weather = weather.to_frame()
weather.index.rename('weather', inplace=True)
weather = weather.rename(columns={'C_WTHR':'Total'})
weather
# Out:
#           Total
# weather
# 1        122076
# 3         16616
# 2         14200
# 4          8943
# 6          2541
# 5           768
# 7           502

# %%
weather.plot(kind='bar', figsize=(10,6))
plt.title('Accidents according to Weather')
positions = (0, 1, 2,3,4,5,6)
labels = ("Clear and sunny", "Raining", "Overcast", "Snowing", "Freezing", "Visibility limitation", "Strong wind")
plt.xticks(positions, labels)
plt.show()

# %% [markdown]
# ## Relationship between Road Surface and accidents

# %%
surface = df_acc['C_RSUR'].value_counts()
surface = surface.to_frame()
surface.index.rename('surface', inplace=True)
surface = surface.rename(columns={'C_RSUR':'Total'})
surface
# Out:
#           Total
# surface
# 1        117445
# 2         29514
# 5          8672
# 3          7077
# 4          2276
# 6           559
# 7            65
# 8            26
# 9            12

# %%
surface.plot(kind='bar', figsize = (10,6))
plt.title('Accidents according to Road Surface')
positions1 = (0, 1, 2,3,4,5,6,7,8)
labels1 = ("Dry/normal", "Wet", "Icy", "Snow", "Slush/wet/snow", "Sand/gravel/dirt", "Muddy", "Oil", "Flooded")
plt.xticks(positions1, labels1)
plt.show()

# %% [markdown]
# ## Relationship between age and accidents

# %%
age = df_acc['P_AGE'].value_counts()
age = age.to_frame()
age.index.rename('age', inplace=True)
age = age.rename(columns={'P_AGE':'Total'})
age.reset_index(inplace=True)
age = age.astype({"age": int})
age.sort_values(by="age", inplace=True)
age
# Out:
#     age  Total
# 48    1   1562
# 72    2    791
# 64    3    872
# 62    4    878
# 65    5    869
# 67    6    863
# 61    7    894
# 60    8    903
# 63    9    876
# 59   10    907
# 70   11    823
# 73   12    776
# 71   13    794
# 66   14    865
# 56   15   1044
# 45   16   1860
# 6    17   3687
# 1    18   3877
# 4    19   3822
# 0    20   3967
# 3    21   3831
# 2    22   3865
# 5    23   3764
# 7    24   3674
# 8    25   3611
# 9    26   3536
# 10   27   3428
# 11   28   3097
# 13   29   3000
# 12   30   3004
# ..  ...    ...
# 55   70   1146
# 57   71    943
# 58   72    929
# 68   73    853
# 69   74    832
# 74   75    762
# 75   76    689
# 76   77    656
# 77   78    603
# 78   79    543
# 79   80    521
# 80   81    497
# 81   82    419
# 82   83    419
# 84   84    332
# 83   85    351
# 85   86    276
# 86   87    241
# 87   88    167
# 88   89    139
# 89   90    101
# 90   91     87
# 91   92     48
# 92   93     37
# 94   94     25
# 93   95     26
# 95   96     16
# 98   97      8
# 96   98     12
# 97   99     11
#
# [99 rows x 2 columns]

# %%
age.plot(kind='line', x='age' ,figsize=(10, 6))
plt.title('Accidents according to age')
plt.show()

# %% [markdown]
# ## Relationship between sex and accidents

# %%
sex = df_acc['P_SEX'].value_counts()
sex = sex.to_frame()
sex.index.rename('sex', inplace=True)
sex = sex.rename(columns={'P_SEX':'Total'})
sex.reset_index(inplace=True)
sex
# Out:
#   sex  Total
# 0   M  88118
# 1   F  77528

# %%
sex.plot(kind='bar', x='sex' ,figsize=(10, 6))
plt.title('Accidents according to Sex')
plt.show()

# %% [markdown]
# ## Relationship between Vehicle model year and accidents

# %%
Vehicle_year = df_acc['V_YEAR'].value_counts()
Vehicle_year = Vehicle_year.to_frame()
Vehicle_year.index.rename('Vehicle model year', inplace=True)
Vehicle_year = Vehicle_year.rename(columns={'V_YEAR':'Total'})
Vehicle_year.reset_index(inplace=True)
Vehicle_year
# Out:
#    Vehicle model year  Total
# 0                2016  12441
# 1                2015  11817
# 2                2014  11059
# 3                2013  10959
# 4                2007  10645
# 5                2010  10329
# 6                2008  10311
# 7                2012  10307
# 8                2006   9512
# 9                2009   9318
# 10               2011   8949
# 11               2017   8780
# 12               2005   8617
# 13               2004   6732
# 14               2003   6449
# 15               2002   4681
# 16               2001   3353
# 17               2000   2762
# 18               1999   1881
# 19               1998   1641
# 20               1997   1049
# 21               2018    642
# 22               1995    591
# 23               1996    589
# 24               1994    360
# 25               1993    333
# 26               1992    286
# 27               1991    203
# 28               1990    180
# 29               1989    137
# ..                ...    ...
# 42               1974     19
# 43               1975     15
# 44               1976     13
# 45               1973     11
# 46               1972     10
# 47               1970     10
# 48               1967     10
# 49               1969     10
# 50               1964      7
# 51               1957      5
# 52               1955      4
# 53               1962      4
# 54               1971      4
# 55               1966      3
# 56               1950      3
# 57               1931      3
# 58               1937      2
# 59               1968      2
# 60               1956      2
# 61               1949      1
# 62               1929      1
# 63               1939      1
# 64               1941      1
# 65               1959      1
# 66               1960      1
# 67               1928      1
# 68               1958      1
# 69               1935      1
# 70               1951      1
# 71               1948      1
#
# [72 rows x 2 columns]

# %%
Vehicle_year.plot(kind='line', x='Vehicle model year' ,figsize=(10, 6))
plt.title('Accidents according to Vehicle model year')
plt.show()

# %%
df_acc['C_RCFG'].replace({'01':'Non-intersection', '02':'At an intersection of at least two public roadways', '03':'Intersection with parking lot ', '04':'Railroad level crossing', '05':'Bridge/overpass/viaduct', '06':'Tunnel/underpass', '07':'Passing/climbing lane', '08':'Ramp','09':'Traffic circle','10':'Express lane','11':'Collector lane','12':'Transfer lane'}, inplace=True)

# %%
r_cfg = df_acc['C_RCFG'].value_counts()
r_cfg = r_cfg.to_frame()
r_cfg.index.rename('Road Config', inplace=True)
r_cfg = r_cfg.rename(columns={'C_RCFG':'Total'})
r_cfg.reset_index(inplace=True)
r_cfg
# Out:
#                                          Road Config  Total
# 0  At an intersection of at least two public road...  84142
# 1                                   Non-intersection  72471
# 2                     Intersection with parking lot    6334
# 3                            Bridge/overpass/viaduct   1598
# 4                            Railroad level crossing    408
# 5                                               Ramp    350
# 6                                   Tunnel/underpass    161
# 7                                     Traffic circle    158
# 8                                       Express lane     12
# 9                              Passing/climbing lane     12

# %%
r_cfg.plot(kind='bar', x='Road Config' ,figsize=(10, 6))
plt.title('Accidents according to Road Config')
plt.show()

# %%
sev = df_acc['C_SEV'].value_counts()
sev = sev.to_frame()
sev.index.rename('sev', inplace=True)
sev = sev.rename(columns={'C_SEV':'Total'})
sev.reset_index(inplace=True)
sev
# Out:
#    sev   Total
# 0    2  163342
# 1    1    2304

# %%
sev.plot(kind = 'bar')
plt.show()
